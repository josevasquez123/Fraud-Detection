# %%
import pandas as pd

# %% [markdown]
# ### EXPLORING DATA

# %%
df = pd.read_csv('../dataset/creditcardfraud.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()          #AS YO CAN SEE, THERE IS AN IMBALANCED DATA
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.isna().sum().max()                  #NO NULL VALUES, DATA IS CLEAN
# Out:
# 0

# %% [markdown]
# ### EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df, x='Class')
plt.title('Class Distribution')
plt.show()

# %%
for index, column_value in  enumerate(df.drop(columns=['Time','Amount','Class'])):
    plt.figure(index)
    plt.title(f'{column_value} Box Plot')
    sns.boxplot(data=df, x='Class', y=column_value)
# Out:
# C:\Users\josem\AppData\Local\Temp\ipykernel_7512\3684167460.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(index)

# %% [markdown]
# EDA GRAPHICS WERE IMPLEMENTED BY BOXPLOTS BECAUSE ALL FEATURES ARE UNKNOWNS. \
# WITH BOXPLOTS WE CAN SEE THE DATA DISTRIBUTION THROUGHOUT FEATURES AND WE CAN SEE ATIPIC VALUES IN MOST OF THEM

# %% [markdown]
# ### DATA MODELLING

# %% [markdown]
# ALL DATA IS NUMERICAL AND CLASS COLUMN IS AS 0 AND 1, FOR THAT REASON WE JUST PASS THIS SESSION ABOUT:
# - MODELLING COLUMNS
# - CONVERT CATEGORICAL TO NUMERICAL VALUES
# - EXTRACT FEATURES

# %% [markdown]
# ### ML MODEL

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### SPLIT AND OVERSAMPLING DATA

# %%
x = df.drop('Class', axis=1)
y= df['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
#UMBALANCED DATA

y_train.value_counts()
# Out:
# 0    227444
# 1       401
# Name: Class, dtype: int64

# %%
sm = SMOTE(sampling_strategy='minority')

# %%
x_train_res, y_train_res = sm.fit_resample(x_train, y_train)

# %%
#AFTER OVERSAMPLING, DATA IS BALANCED

y_train_res.value_counts()
# Out:
# 0    227444
# 1    227444
# Name: Class, dtype: int64

# %% [markdown]
# #### LOGISTIC MODEL

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(x_train_res, y_train_res)
# Out:
# d:\AnalisisDatos\Portfolio\FraudDetection\env\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logistic_model.predict(x_test)

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56871
#            1       0.07      0.95      0.13        91
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.96      0.56     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[55755  1116]
#  [    5    86]]

# %% [markdown]
# #### RANDOM FOREST MODEL

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=20)

# %%
rf_model.fit(x_train_res, y_train_res)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_pred_rf = rf_model.predict(x_test)

# %%
print(metrics.classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56871
#            1       0.89      0.91      0.90        91
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.96      0.95     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
metrics.confusion_matrix(y_test, y_pred_rf)
# Out:
# array([[56861,    10],
#        [    8,    83]], dtype=int64)

# %% [markdown]
# PRECISION, RECALL AND F1-SCORE FOR 1 CLASS (UNBALANCED DATA) PRESENT A GOOD VALUES\
# IN ORDER OF THAT WE CAN ACCEPT THIS MODEL TO MAKE FUTURE PREDICTIONS

# %% [markdown]
# ### DELET OUTLIERS FROM DATA

# %%
from datasist.structdata import detect_outliers

# %%
df_columns = df.drop(columns=['Class', 'Time', 'Amount'], axis=1)
df_columns.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
outlier_indices = detect_outliers(df,0,df_columns.columns)
df_no_outliers = df.drop(outlier_indices)

# %%
for index, column_value in  enumerate(df_no_outliers.drop(columns=['Time','Amount','Class'])):
    plt.figure(index)
    plt.title(f'{column_value} Box Plot')
    sns.boxplot(data=df_no_outliers, x='Class', y=column_value)
# Out:
# C:\Users\josem\AppData\Local\Temp\ipykernel_2512\1044909548.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(index)

# %% [markdown]
# AS YOU CAN SEE, BOXPLOTS SHOW THAT WE REMOVE OUTLIERS

# %% [markdown]
# ### ML MODEL

# %% [markdown]
# #### SPLIT AND OVERSAMPLING DATA

# %%
df_no_outliers['Class'].value_counts()
# Out:
# 0    156135
# 1        15
# Name: Class, dtype: int64

# %%
x = df_no_outliers.drop('Class', axis=1)
y = df_no_outliers['Class']

# %%
y.value_counts()
# Out:
# 0    156135
# 1        15
# Name: Class, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
sm = SMOTE(sampling_strategy='minority')

# %%
x_train_res, y_train_res = sm.fit_resample(x_train, y_train)

# %% [markdown]
# THERE ARE FEW CLASS VALUES AS "1", FOR THAT REASON WE GET A FAIL MODELS \
# WE HAVE 15 VALUE AS CLASS "1",CONSEQUENTLY WE HAVE A VERY LITTLE Y_TEST VALUES AND THAT IS NOT ENOUGH TO GET A RELIABLE PREDICT VALUES

# %% [markdown]
# #### RANDOM FOREST MODEL

# %%
rf_model = RandomForestClassifier(n_estimators=20)

# %%
rf_model.fit(x_train_res, y_train_res)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_pred_rf = rf_model.predict(x_test)

# %%
print(metrics.classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31226
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     31230
#    macro avg       0.50      0.50      0.50     31230
# weighted avg       1.00      1.00      1.00     31230

# %%
metrics.confusion_matrix(y_test, y_pred_rf)
# Out:
# array([[31224,     2],
#        [    4,     0]], dtype=int64)

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# - RANDOM FOREST MODEL GETS THE BEST RESULTS
# - WE USE RANDOM FOREST MODEL BEFORE DROP OUTLIERS
# - DROP OUTLIERS ALSO DROP Y CLASS VALUES
# - NEXT OCASION, WE HAVE TO USE ANOTHER OUTLIER METHOD
